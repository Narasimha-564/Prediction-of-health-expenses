# %% [markdown]
# ### Mount the given datasets in your python environment and perform and produce the following outcomes
# ### 1. By using previous data sets implement CRISP-DM model under the following and extract visualizations in depth CRISP-DM Model generation
# ### Describe the note of CRISP-DM clearly, for client understand way
# ### 1) Model Building
# ### 2) Model Evaluation for
# ### 3) Log transform
# ### 4) Check for Linearity
# ### 5) Check for Multivariate Normality
# ### 6) Create Visualizing our decision tree model
# ### 7) Bagging methods & Boosting methods
# ### 8) Generates violin plots with description

# %% [markdown]
# Implement your code here

# %% [markdown]
# ### Mount the given datasets in your python environment and perform and produce the following outcomes

# %% [markdown]
# # CRISP-DM MODEL

# %% [markdown]
# ### Cross Industry Standard Process for Data Mining
# **Cross-Industry Standard Process for Data Mining** (CRISP-DM) developed in 1996
# * Fits data mining into the general problem-solving strategy of business/research unit
# * Contributors include DaimlerChrysler, SPSS, and NCR
# * Industry, tool and application neutral
# * Non-proprietary and freely available
#
# Extension:
# * In 2015, IBM released an extension:  **Analytics Solutions Unified Method for Data Mining/Predictive Analytics**(ASUM-DM)

# %% [markdown]
# ### CRISP-DM: Phase 1
# (1) **Business/Research Understanding Phase**
# * Define project requirements and objectives
# * Translate objectives into data mining problem definition
# * Prepare preliminary strategy to meet objectives
#
# Health care project
# * What are project requirements and objectives?
# * Translate objectives into data mining problem definition: classification, not regression, not clustering, not forecasting
# * Prepare preliminary strategy to meet objectives: select Python language,  ……

# %% [markdown]
# ### CRISP-DM: Phase 2
# (2) **Data Understanding Phase**
# * Collect data
# * Perform exploratory data analysis (EDA)
# * Assess data quality
# * Optionally, select interesting subsets
#
# Health care project
# * Where to collect data?
# * Perform exploratory data analysis (EDA): draw figures for understanding the data
# * Assess data quality: is any wrong value? is there any missing value?

# %% [markdown]
# ### CRISP-DM: Phase 3
# **(3) Data Preparation Phase**
# * Prepares for modeling in subsequent phases
# * Select cases and variables appropriate for analysis
# * Cleanse and prepare data so it is ready for modeling tools
# * Perform transformation of certain variables, if needed
#
# Health care project
# * Features: age,sex,bmi,children,smoker,region,expenses
# * Target: prediction of expenses
# * Do we need data cleansing for missing values or wrong values? Do we need data transformation? and how?

# %% [markdown]
# ### CRISP-DM: Phase 4
# **(4) Modeling Phase**
# * Select and apply one or more modeling techniques
# * Calibrate model settings to optimize results
# * If necessary,  additional data preparation may be required for supporting a particular technique
#
# Health care project:
# * Which model?
# * How to train the model?

# %% [markdown]
# ### CRISP-DM: Phase 5
# **(5) Evaluation Phase**
# * Evaluate one or more models for effectiveness
# * Determine whether defined objectives achieved
# * Establish whether some important facet of the problem has not been sufficiently accounted for
# * Make decision regarding data mining results before deploying to field
#
# Health care project
# * How to evaluate the performance of the model?
# * Does the model satisfiy the project requirement?

# %% [markdown]
# ### CRISP-DM: Phase 6
# **(6) Deployment Phase**
# * Make use of models created
# * Simple deployment example: generate report
# * Complex deployment example: implement parallel data mining effort in another department
# * In businesses, customer often carries out deployment based on your model
#
# Health care project
# * How to make use of the model? write mannual?
# * Write a techinical report?

# %% [markdown]
# ### CRISP-DM: Six Phases
# Data mining projects follow iterative, adaptive life cycle consisting of six phases.
#
# |![image.png](attachment:image.png)|
# |:--:|
# |[Six phases of CRISP-DM](https://upload.wikimedia.org/wikipedia/commons/thumb/b/b9/CRISP-DM_Process_Diagram.png/330px-CRISP-DM_Process_Diagram.png)|

# %% [markdown]
# ### Follow CRISP-DM six phases
# 1. Understand project business: business purpose is to find the purchase of medicines and accessories.
# 2. Understand data: describe data, such as the number of records; range of length, etc.
# 3. Prepare data for data mining: check missing data, incorrect data, repeated data.
# 4. Build model: select one of the prediction algorithm(decision tree regressor); train the model on the dataset obtained after preparing the data
# 5. Evaluate model: evaluate one or more prediction algorithm for effectiveness; check predictive accuracy
# 6. Deploy model: write a project report

# %% [markdown]
# ### Step by step Python implementation
# 1. Loading the data set
# 2. Understand the data
# 3. Build a model
# 4. Evaluate the model

# %% [markdown]
# ### Import and check libraries
# * Import library: `pandas` for representing data;

# %%
import pandas as pd

# %% [markdown]
# ### Load Data
# * Use Python library pandas to load the data.
# * Pandas is common Python Data Analysis Library
# * `pd.read_csv` read the CSV to a data frame (= a spread sheet)

# %%
insurance_df=pd.read_csv('insurance.csv')
insurance_df
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 1      18    male  33.8         1     no  southeast   1725.55
# 2      28    male  33.0         3     no  southeast   4449.46
# 3      33    male  22.7         0     no  northwest  21984.47
# 4      32    male  28.9         0     no  northwest   3866.86
# ...   ...     ...   ...       ...    ...        ...       ...
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [1338 rows x 7 columns]

# %% [markdown]
# ### Check the data shape
# * Check how rows and how many columns.

# %%
#checking the shape of the dataset
insurance_df.shape
# Out:
# (1338, 7)

# %% [markdown]
# ### Understand data
# * Print first 5 samples
# * Print last 5 samples

# %%
#first five samples of the dataset
insurance_df.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %%
#last five samples of the dataset
insurance_df.tail()
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36

# %% [markdown]
# ### Check number of instances in each class
# * Count instances in each class
# * Pandas groupby function
# * `insurance_df.groupby('class').size()`: group data by the column of **expenses** and calculate the group size

# %%
# class distribution
print(insurance_df.groupby('expenses').size())
# Out:
# expenses
# 1121.87     1
# 1131.51     1
# 1135.94     1
# 1136.40     1
# 1137.01     1
#            ..
# 55135.40    1
# 58571.07    1
# 60021.40    1
# 62592.87    1
# 63770.43    1
# Length: 1337, dtype: int64

# %%
#describing the dataset
insurance_df.describe()
# Out:
#                age          bmi     children      expenses
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.665471     1.094918  13270.422414
# std      14.049960     6.098382     1.205493  12110.011240
# min      18.000000    16.000000     0.000000   1121.870000
# 25%      27.000000    26.300000     0.000000   4740.287500
# 50%      39.000000    30.400000     1.000000   9382.030000
# 75%      51.000000    34.700000     2.000000  16639.915000
# max      64.000000    53.100000     5.000000  63770.430000

# %% [markdown]
# ### Exploratory data analysis
# * EDA is to visualise data for understudying data
# * Plot histograms: `df.hist()` is a data frame built-in method for plotting histograms

# %%
# Plot histograms
import matplotlib.pyplot as plt
insurance_df.hist()
plt.show()

# %% [markdown]
# * The above histograms shows the distribution of each column in the dataset

# %% [markdown]
# ### Check for the null values in the dataset

# %%
insurance_df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# expenses    0
# dtype: int64

# %% [markdown]
# * There are no null values in the entire dataset

# %% [markdown]
# ### Checking linear relation between age and expenses

# %%
#drawing a lineplot between age and expenses
import seaborn as sns
sns.lineplot(data=insurance_df, x="age", y="expenses")
# Out:
# <AxesSubplot:xlabel='age', ylabel='expenses'>

# %% [markdown]
# * By seeing the line plot we can say there is a co-relation between age and expenses

# %% [markdown]
# ### Checking for the outliers in the age column

# %%
#Checking for outliers in the age column
import seaborn as sns
sns.boxplot(data=insurance_df,x="age")
# Out:
# <AxesSubplot:xlabel='age'>

# %% [markdown]
# * By seeing the above **box plot** we can say there are **no outliers** in the **age** column

# %% [markdown]
# ### Checking for the outliers in the bmi column

# %%
#Checking for the outliers in the bmi column
sns.boxplot(data=insurance_df,x="bmi")
# Out:
# <AxesSubplot:xlabel='bmi'>

# %% [markdown]
# * By seeing the above **box plot** we can say there are **outliers** in the **bmi** column

# %% [markdown]
# ### Prepare Data:  Cleaning the data

# %% [markdown]
# ### Cleaning the outliers in the bmi column

# %%
#removing the outliers in the bmi column
insurance_df = insurance_df[insurance_df['bmi']<46]

# %%
sns.boxplot(data=insurance_df,x="bmi")
# Out:
# <AxesSubplot:xlabel='bmi'>

# %% [markdown]
# * By seeing the boxplot we can say the outliers are removed from the bmi column

# %% [markdown]
# ### Transforming the categorical column values in the dataset to numerical values

# %% [markdown]
# * creating a seperate dataframe for the categorical value columns

# %%
df_cat = insurance_df[['sex','smoker','region']]
df_cat
# Out:
#          sex smoker     region
# 0     female    yes  southwest
# 1       male     no  southeast
# 2       male     no  southeast
# 3       male     no  northwest
# 4       male     no  northwest
# ...      ...    ...        ...
# 1333    male     no  northwest
# 1334  female     no  northeast
# 1335  female     no  southeast
# 1336  female     no  southwest
# 1337  female    yes  northwest
#
# [1322 rows x 3 columns]

# %% [markdown]
# * Converting the categorical values into numericals
# * Usong pd.get_dumies(df_cat)

# %%
#converting the categorical values into numericals
df_encoded = pd.get_dummies(df_cat)

# %% [markdown]
# ### Adding the newly formed numerical columns into the dataset

# %%
#addig the newly formed numerical columns into the dataset
data_transformed = pd.concat([insurance_df,df_encoded], axis=1)
data_transformed
# Out:
#       age     sex   bmi  children smoker     region  expenses  sex_female  \
# 0      19  female  27.9         0    yes  southwest  16884.92           1
# 1      18    male  33.8         1     no  southeast   1725.55           0
# 2      28    male  33.0         3     no  southeast   4449.46           0
# 3      33    male  22.7         0     no  northwest  21984.47           0
# 4      32    male  28.9         0     no  northwest   3866.86           0
# ...   ...     ...   ...       ...    ...        ...       ...         ...
# 1333   50    male  31.0         3     no  northwest  10600.55           0
# 1334   18  female  31.9         0     no  northeast   2205.98           1
# 1335   18  female  36.9         0     no  southeast   1629.83           1
# 1336   21  female  25.8         0     no  southwest   2007.95           1
# 1337   61  female  29.1         0    yes  northwest  29141.36           1
#
#       sex_male  smoker_no  smoker_yes  region_northeast  region_northwest  \
# ...

# %% [markdown]
# ### Dropping the unnecessary columns from the transformed dataset

# %%
data_transformed.drop(['sex','smoker','region'],axis = 1,inplace = True)

# %%
data_transformed.drop(['sex_female','smoker_no','region_northeast'],axis = 1,inplace = True)

# %%
#final transformed dataframe
data_transformed
# Out:
#       age   bmi  children  expenses  sex_male  smoker_yes  region_northwest  \
# 0      19  27.9         0  16884.92         0           1                 0
# 1      18  33.8         1   1725.55         1           0                 0
# 2      28  33.0         3   4449.46         1           0                 0
# 3      33  22.7         0  21984.47         1           0                 1
# 4      32  28.9         0   3866.86         1           0                 1
# ...   ...   ...       ...       ...       ...         ...               ...
# 1333   50  31.0         3  10600.55         1           0                 1
# 1334   18  31.9         0   2205.98         0           0                 0
# 1335   18  36.9         0   1629.83         0           0                 0
# 1336   21  25.8         0   2007.95         0           0                 0
# 1337   61  29.1         0  29141.36         0           1                 1
#
#       region_southeast  region_southwest
# ...

# %% [markdown]
# ### Heatmap of correlation

# %%
sns.heatmap(data_transformed.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Prepare Data: sperate features and target
# * Columns: age,bmi,children,smoker,region are features
# * Column: expenses is the target

# %%
X = data_transformed.drop('expenses',axis=1)
Y = data_transformed['expenses']

# %% [markdown]
# ### Prepare Data: training and test data
# * We must split data into training and test data.
# * Why?
# * Assume we train a police dog for detecting drugs.
# * We train the daog with parcels with labels (with drug or without) first (training)
# * Then we test the performance of the dog on other parcels and check the accuracy of detecting drugs

# %% [markdown]
# ### Prepare Data: training and test data
# * We split data: 70% of data as a training dataset and 30% for test
# * `train_test_split(X, y, test_size=0.3, random_state=46)`: input feature data X, and label data y
# * return four features and label data on training and test data
# * Splitting is random, relying on a parameter: random_state. We set `random_state=46` for repeating same results

# %%
from sklearn.model_selection import train_test_split # Import train_test_split function
#Split dataset into training set and test set
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=46) # 70% training and 30% test
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=10) # 50% training and 50% test with random state = 10
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (925, 8)
# (397, 8)
# (925,)
# (397,)

# %% [markdown]
# ### Build Model
# * We choose decision tree as our model. A decision tree is very intuitive can be interpreted as IF THEN rules

# %%
# Import Decision Tree Regressor
from sklearn.tree import DecisionTreeRegressor 
# Create Decision Tree Regressor object
dtr = DecisionTreeRegressor(max_depth = 4)

# %% [markdown]
# * `DecisionTreeRegressor(max_depth = 4)` return a regressor object(we name it `dtr` )
# * `max_depth = 4` is a parameter

# %% [markdown]
# ### Model Building
# * Training is called fit: fit the model with the data

# %%
# Train Decision Tree Regressor
dtr = dtr.fit(X_train,Y_train)

# %% [markdown]
# ### Evaluate the model
# * We apply the model to test data and make prediction of the class lable of test data
# * First we apply the model `dtr` on test data `X_test`. This returns predicted labels for each sample `Y_pred` on test data
# * We use `r2_score(Y_test, Y_pred)` to compare the difference between predicted labels and actual labels.It is a mathematical formula to evaluatet accuracy

# %%
#Import scikit-learn metrics module for r2 score calculation
from sklearn.metrics import  r2_score
#Predict the response for test dataset
Y_pred = dtr.predict(X_test)
# Model Accuracy, how often is the regressor correct?
print("Accuracy:",r2_score(Y_test, Y_pred))
# Out:
# Accuracy: 0.7915705785099192

# %% [markdown]
# ### Log Transformation

# %% [markdown]
# * Log transformation helps reducing skewness when you have skewed data.
# * It is used for Transformation for continuous variables
# * We have 4 columns having continuous variables.
# * Apply log tranformation for the for columns

# %% [markdown]
# ### log transformation for expenses column

# %%
#displaying the distribution plot of expenses column before log transformation
sns.displot(data=insurance_df, x="expenses",kde=True)
plt.title("Before log transformation expenses column")
# Out:
# Text(0.5, 1.0, 'Before log transformation expenses column')

# %%
#creating log transformed expenses column 
import numpy as np
insurance_df['log_expenses'] = np.log(data_transformed['expenses'])
#displaying the log tranformed expenses column using distribution plot
sns.displot(data=insurance_df, x="log_expenses",kde=True)
plt.title("After log transformation expenses column")
# Out:
# C:\Users\Lenovo\AppData\Local\Temp/ipykernel_13348/2384467576.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   insurance_df['log_expenses'] = np.log(data_transformed['expenses'])
# Text(0.5, 1.0, 'After log transformation expenses column')

# %% [markdown]
# ### Log transformation for age column

# %%
#displaying the distribution plot of age column before log transformation
sns.displot(data=insurance_df, x="age",kde=True)
plt.title("Before log transformation")
# Out:
# Text(0.5, 1.0, 'Before log transformation')

# %%
#creating log transformed age column 
insurance_df['log_age'] = np.log(data_transformed['age'])
#displaying the log tranformed age column using distribution plot
sns.displot(data=insurance_df, x="log_age",kde=True)
plt.title("After log transformation")
# Out:
# C:\Users\Lenovo\AppData\Local\Temp/ipykernel_13348/1998318546.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   insurance_df['log_age'] = np.log(data_transformed['age'])
# Text(0.5, 1.0, 'After log transformation')

# %%
insurance_df['log_age']
# Out:
# 0       2.944439
# 1       2.890372
# 2       3.332205
# 3       3.496508
# 4       3.465736
#           ...
# 1333    3.912023
# 1334    2.890372
# 1335    2.890372
# 1336    3.044522
# 1337    4.110874
# Name: log_age, Length: 1322, dtype: float64

# %% [markdown]
# ### Log transformation for bmi column

# %%
#displaying the distribution plot of bmi column before log transformation
sns.displot(data=insurance_df, x="bmi",kde=True)
plt.title("Before log transformation")
# Out:
# Text(0.5, 1.0, 'Before log transformation')

# %%
#creating log transformed bmi column 
import numpy as np
insurance_df['log_bmi'] = np.log(data_transformed['bmi'])
#displaying the log tranformed bmi column using distribution plot
sns.displot(data=insurance_df, x="log_bmi",kde=True)
plt.title("After log transformation")
# Out:
# C:\Users\Lenovo\AppData\Local\Temp/ipykernel_13348/536665888.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   insurance_df['log_bmi'] = np.log(data_transformed['bmi'])
# Text(0.5, 1.0, 'After log transformation')

# %% [markdown]
# ### Check for Linearity
# * checking whether there is linearity between two columns for whole dataset.
# * It is checked by using df.corr() and visualizing it by using heatmap.
# * Individually we can visualize it using lineplot.

# %%
#checking the linearity between all columns of the dataset
data_transformed.corr()
# Out:
#                        age       bmi  children  expenses  sex_male  \
# age               1.000000  0.114275  0.041166  0.302307 -0.015725
# bmi               0.114275  1.000000  0.006526  0.197845  0.043051
# children          0.041166  0.006526  1.000000  0.073468  0.020046
# expenses          0.302307  0.197845  0.073468  1.000000  0.067082
# sex_male         -0.015725  0.043051  0.020046  0.067082  1.000000
# smoker_yes       -0.024564 -0.000409  0.011358  0.785155  0.081716
# region_northwest  0.000317 -0.122971  0.026637 -0.037827 -0.010453
# region_southeast -0.011620  0.243361 -0.024368  0.071945  0.009959
# region_southwest  0.009255  0.003816  0.021111 -0.045866  0.000120
#
#                   smoker_yes  region_northwest  region_southeast  \
# age                -0.024564          0.000317         -0.011620
# bmi                -0.000409         -0.122971          0.243361
# children            0.011358          0.026637         -0.024368
# ...

# %%
#visualizing the correlation using heatmap
sns.heatmap(data_transformed.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# * From the heatmap and the correlation
# * The target column expenses is positively linear with the columns : smoker_yes,age,male in decreasing order respectively.
# * All other columns doesn't have any linearity with expenses column.

# %% [markdown]
# ### Visualizing the linearity between the columns seperately

# %%
sns.lineplot(data=data_transformed, x="smoker_yes", y="expenses")
# Out:
# <AxesSubplot:xlabel='smoker_yes', ylabel='expenses'>

# %% [markdown]
# * smoker_yes and expenses columns are highly linear

# %%
sns.lineplot(data=data_transformed, x="age", y="expenses")
# Out:
# <AxesSubplot:xlabel='age', ylabel='expenses'>

# %% [markdown]
# * age and expenses columns are medium linear

# %%
sns.lineplot(data=data_transformed, x="bmi", y="expenses")
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='expenses'>

# %% [markdown]
# * bmi and expenses are slightly linear

# %% [markdown]
# ### Check for Multivariate Normality
# * This is a hypotheses test and the two hypotheses are as follows:
#
# * H0 (accepted): The variables follow a multivariate normal distribution.(pval>0.5)
# * Ha (rejected): The variables do not follow a multivariate normal distribution

# %% [markdown]
# * To check Multivariate normality we use multivariate function from pingouin module

# %%
from pingouin import multivariate_normality

# %%
multivariate_normality(data_transformed, alpha=.05)
# Out:
# HZResults(hz=8.879744596293342, pval=0.0, normal=False)

# %% [markdown]
# * The variables do not follow a multivariate normal distribution

# %% [markdown]
# ### Visualizing the Decision Tree

# %% [markdown]
# * Using graphviz tool to visualize the decision tree
# * Using we convert the decision tree into the .dot file
# * then we convert the .dot file into .png file using online convertor and display the decision tree

# %%
feature_name=['age','bmi','children','sex_male','smoker_yes','region_northwest','region_southeast','region_southwest']

# %%
#converting the visualized decision tree into .dot file
from sklearn.tree import export_graphviz
export_graphviz(dtr, 'tree.dot', feature_names = feature_name)

# %%
#after converting the .dot file into .png file
#displaying the decision tree
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline
img = cv2.imread('tree.png')
plt.figure(figsize = (20, 20))
plt.imshow(img)
plt.show()

# %% [markdown]
# ### Bagging Method

# %% [markdown]
# * Bagging method is a ensemble technique which is used to increase the accuracy of the model.
# * It is helps to decrease the "Varience" of the model and to increase the accurcy of the model.

# %%
#importing the bagging regressor algorithm 
from sklearn.ensemble import BaggingRegressor
#Building the bagging model
regr = BaggingRegressor(base_estimator=dtr,n_estimators=5, random_state=0).fit(X_train, Y_train)
#predicting the expenses
y_pred=regr.predict(X_test)
#Checking the accuracy
print("Accuracy:",r2_score(Y_test, y_pred))
# Out:
# Accuracy: 0.7945588147604572

# %% [markdown]
# ### Boosting Method

# %% [markdown]
# * Boostig method is a ensemble technique which is used to increase the accuracy of the model.
# * It is helps to decrease the "Varience and bias" of the model and to increase the accurcy of the model.

# %%
#importing the boosting method algorithm adaboost regressor 
from sklearn.ensemble import AdaBoostRegressor
#Building the Adaboost regressor model
regr_2 = AdaBoostRegressor(base_estimator=dtr,n_estimators=5, random_state=0).fit(X_train, Y_train)
#Predicting the values using the model
ypred=regr_2.predict(X_test)
#Checking the accuracy
print("Accuracy:",r2_score(Y_test, ypred))
# Out:
# Accuracy: 0.7990139664510958

# %% [markdown]
# ### Violin plots

# %%
sns.violinplot(x=data_transformed["age"])
# Out:
# <AxesSubplot:xlabel='age'>

# %% [markdown]
# * Above violinpolt shows the distribution of age in a range of (10,70)

# %%
sns.violinplot(x=data_transformed["bmi"])
# Out:
# <AxesSubplot:xlabel='bmi'>

# %% [markdown]
# * Above violin plot shows the distribution of bmi in a range of (0,50)

# %%
sns.violinplot(x=data_transformed["smoker_yes"])
# Out:
# <AxesSubplot:xlabel='smoker_yes'>

# %% [markdown]
# * Above violin plot shows the yes and no value distribution of smoker

# %%
sns.violinplot(x=data_transformed["expenses"])
# Out:
# <AxesSubplot:xlabel='expenses'>

# %% [markdown]
# * Above violin plot shows the distribution of expenses in a range of (0,70000)

# %%
sns.set(rc={'figure.figsize':(20,20)})
sns.violinplot(data=data_transformed, x="age", y="expenses")
# Out:
# <AxesSubplot:xlabel='age', ylabel='expenses'>

# %% [markdown]
# * This violin plot shows the relation between the age and the purchase cost of medicines and the expenses

# %%
sns.violinplot(data=data_transformed, x="smoker_yes", y="expenses")
# Out:
# <AxesSubplot:xlabel='smoker_yes', ylabel='expenses'>

# %% [markdown]
# * This violin plot shows that the people who have the habit of smoking needs to spend more money for buying medicines than the non smoker people
